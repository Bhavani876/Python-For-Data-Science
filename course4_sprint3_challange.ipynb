# %% [markdown]
# # course_4 challange

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('DS1_C4_S3_Loan_Data_Challenge.csv.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# # task 1

# %%
x=df[(df['ApplicantIncome']< 6000) & (df['LoanAmount']> 200) & (df['Loan_Status']=='Y')][['Loan_ID','Gender']]
x
# Out:
#       Loan_ID  Gender
# 5    LP001011    Male
# 21   LP001046    Male
# 159  LP001552    Male
# 253  LP001843    Male
# 255  LP001846  Female
# 276  LP001903    Male
# 361  LP002170    Male
# 381  LP002229    Male
# 502  LP002615    Male
# 505  LP002622    Male
# 530  LP002717    Male
# 562  LP002820    Male

# %%
x['Gender'].value_counts()
# Out:
# Male      11
# Female     1
# Name: Gender, dtype: int64

# %% [markdown]
# # task 2

# %%
x1=df[(df['Property_Area']=='Semiurban')]
a=x1.shape[0]
a
# Out:
# 233

# %%
x1=df[(df['Property_Area']=='Urban')]
b=x1.shape[0]
b
# Out:
# 202

# %%
c=b-a
x1
# Out:
# 201.0

# %%
x11=df[(df['Property_Area']=='Semiurban') | (df['Property_Area']=='Urban')]

# %%
x11.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 2             3000                0.0          66               360
# 3             2583             2358.0         120               360
# 4             6000                0.0         141               360
# 5             5417             4196.0         267               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 2               1         Urban           Y
# ...

# %%
x11['Property_Area'].value_counts(normalize=True)*100
# Out:
# Semiurban    53.563218
# Urban        46.436782
# Name: Property_Area, dtype: float64

# %% [markdown]
# # task 3

# %%
x2 = df[(df['Loan_Status']=='Y')].sort_values('ApplicantIncome')
x2.tail()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 443  LP002422   Male      No          1  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 155  LP001536   Male     Yes         3+  Graduate            No
# 171  LP001585   Male     Yes         3+  Graduate            No
# 333  LP002101   Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 443            37719                0.0         152               360
# 185            39147             4750.0         120               360
# 155            39999                0.0         600               180
# 171            51763                0.0         700               300
# 333            63337                0.0         490               180
#
#      Credit_History Property_Area Loan_Status
# 443               1     Semiurban           Y
# 185               1     Semiurban           Y
# ...

# %%
x2.loc[:5]
# Out:
# 0    5849
# 2    3000
# 3    2583
# 4    6000
# 5    5417
# Name: ApplicantIncome, dtype: int64

# %% [markdown]
# # task 4

# %%
df[(df['Gender']=='Female') & (df['Loan_Status']=='Y') & (df['Dependents']=='2')][['LoanAmount','ApplicantIncome']]
# Out:
#      LoanAmount  ApplicantIncome
# 29          120             3750
# 146          70            14866
# 219         127             4283
# 468          98              210
# 516         113             2031

# %% [markdown]
# # task 5

# %%
df.loc[(df["LoanAmount"] > 200) & (df["Gender"]=='Female'), "Loan_Amount_Term" ] = 180
df.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 488  LP002555    Male     Yes          2      Graduate           Yes
# 293  LP001945  Female      No          2      Graduate            No
# 401  LP002296    Male      No          0  Not Graduate            No
# 567  LP002837    Male     Yes         3+      Graduate            No
# 191  LP001656    Male      No          0      Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 224  LP001750    Male     Yes          0      Graduate            No
# 303  LP001977    Male     Yes          1      Graduate            No
# 553  LP002788    Male     Yes          0  Not Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 488             4583             2083.0         160               360
# ...

# %% [markdown]
# # task 6

# %%
df.rename(columns={'Loan_Amount_Term':'LoanAmountTerm'},inplace=True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0             5849                0.0         146             360
# 1             4583             1508.0         128             360
# 2             3000                0.0          66             360
# 3             2583             2358.0         120             360
# 4             6000                0.0         141             360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %%
df.loc[(df['LoanAmountTerm']==12) | (df['LoanAmountTerm']==36),'LoanAmountTerm']=60
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0             5849                0.0         146             360
# 1             4583             1508.0         128             360
# 2             3000                0.0          66             360
# 3             2583             2358.0         120             360
# 4             6000                0.0         141             360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %%
df['LoanAmountTerm'].replace(to_replace=[12,36],value=60,inplace=True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0             5849                0.0         146             360
# 1             4583             1508.0         128             360
# 2             3000                0.0          66             360
# 3             2583             2358.0         120             360
# 4             6000                0.0         141             360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %%
x3= df[(df.Education == 'Graduate') & (df.Self_Employed == "Yes") & (df.ApplicantIncome > 10000)][['Loan_ID','ApplicantIncome']]
x3.head()
# Out:
#       Loan_ID  ApplicantIncome
# 54   LP001186            11500
# 128  LP001451            10513
# 130  LP001469            20166
# 185  LP001640            39147
# 199  LP001673            11000

# %%
x3['credit_limit']=x3['ApplicantIncome']*2
x3.head()
# Out:
#       Loan_ID  ApplicantIncome  credit_limit
# 54   LP001186            11500         23000
# 128  LP001451            10513         21026
# 130  LP001469            20166         40332
# 185  LP001640            39147         78294
# 199  LP001673            11000         22000

# %% [markdown]
# # task 8

# %%
df.drop(df[(df['Dependents']=='3+') | (df['Credit_History']==0) | (df['Education']=='Not Graduate')].index, inplace = True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0             5849                0.0         146             360
# 1             4583             1508.0         128             360
# 2             3000                0.0          66             360
# 4             6000                0.0         141             360
# 5             5417             4196.0         267             360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# 2               1         Urban           Y
# ...

# %% [markdown]
# # task 9

# %%
df[(df['Education']=='Graduate') | (df['Education']=='Not Graduate')],['ApplicantIncome']
df.head()
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0             5849                0.0         146             360
# 1             4583             1508.0         128             360
# 2             3000                0.0          66             360
# 4             6000                0.0         141             360
# 5             5417             4196.0         267             360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# 2               1         Urban           Y
# ...

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Education'].value_counts(['ApplicantIncome'])*100
# Out:
# Graduate        78.175896
# Not Graduate    21.824104
# Name: Education, dtype: float64
