# %% [markdown]
# # sprint4_challange

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("DS1_C4_S4_Car_Prices_Data_Challenge (1).csv.crdownload")
df
# Out:
#        year    make                model        trim       body transmission  \
# 0      2015     Kia              Sorento          LX        SUV    automatic
# 1      2015     Kia              Sorento          LX        SUV    automatic
# 2      2014     BMW             3 Series  328i SULEV      Sedan    automatic
# 3      2015   Volvo                  S60          T5      Sedan    automatic
# 4      2014     BMW  6 Series Gran Coupe        650i      Sedan    automatic
# ...     ...     ...                  ...         ...        ...          ...
# 41410  2014  Nissan           Versa Note      1.6 SV  Hatchback       manual
# 41411  2014  Nissan               Sentra          SV      Sedan    automatic
# 41412  2014  Nissan           Pathfinder          SV        SUV          NaN
# 41413  2014   Scion                   xD        Base  Hatchback    automatic
# 41414  2014     Ram                 1500    Longhorn   Crew Cab    automatic
#
# ...

# %%
df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %% [markdown]
# # task 1

# %%
x=df[df['year']== 2014][['make','sellingprice']].sort_values(by='sellingprice')
x.head()
# Out:
#             make  sellingprice
# 36340  Chevrolet        1200.0
# 27902      Mazda        1300.0
# 2191   Chevrolet        1400.0
# 5623       Mazda        1500.0
# 7744       Mazda        1500.0

# %% [markdown]
# # task 2

# %%
df[(df['year']==2010) | (df['year']==2015)].head()
# Out:
#     year    make    model   trim   body transmission                vin state  \
# 0   2015     Kia  Sorento     LX    SUV    automatic  5xyktca69fg566472    ca
# 1   2015     Kia  Sorento     LX    SUV    automatic  5xyktca69fg561319    ca
# 3   2015   Volvo      S60     T5  Sedan    automatic  yv1612tb4f1310987    ca
# 5   2015  Nissan   Altima  2.5 S  Sedan    automatic  1n4al3ap1fn326013    ca
# 11  2015     Kia   Optima     LX  Sedan    automatic  5xxgm4a73fg353538    ca
#
#     condition  odometer  color interior  \
# 0         5.0   16639.0  white    black
# 1         5.0    9393.0  white    beige
# 3         4.1   14282.0  white    black
# 5         1.0    5554.0   gray    black
# 11        4.8    2034.0    red      tan
#
#                                                seller      mmr  sellingprice  \
# 0                             kia motors america, inc  20500.0       21500.0
# 1                             kia motors america, inc  20800.0       21500.0
# ...

# %%
df[(df['condition']>4.5) & (df['make']=='BMW')].head()
# Out:
#      year make     model        trim   body transmission                vin  \
# 37   2014  BMW  3 Series  328i SULEV  Sedan    automatic  wba3c1c50ek108497
# 59   2014  BMW        M5        Base  Sedan    automatic  wbsfv9c51ed097712
# 71   2014  BMW        X1   sDrive28i    SUV    automatic  wbavm1c53evw47779
# 106  2014  BMW  5 Series        535d  Sedan    automatic  wbaxa5c52ed689665
# 110  2014  BMW        X5   xDrive35i    SUV    automatic  5uxkr0c54e0k49204
#
#     state  condition  odometer  color interior  \
# 37     ca        5.0     111.0  black        —
# 59     ca        4.7    7766.0   gray    black
# 71     ca        4.8   19689.0  white    black
# 106    ca        4.8   12292.0  white    black
# 110    ca        5.0    4503.0  white    black
#
#                                      seller      mmr  sellingprice  \
# 37   financial services remarketing (lease)  32200.0       30500.0
# 59                fratelli investment group  71000.0       77250.0
# ...

# %%
df= pd.pivot_table(task2_2, index=['year'], values=['sellingprice'], aggfunc=['mean'])
df
# Out:
#              mean
#      sellingprice
# year
# 2015      64000.0

# %% [markdown]
# # task 3

# %%
a=df[(df['color'].isin(['black','gray']))]
a
# Out:
#        year        make     model              trim   body transmission  \
# 5      2015      Nissan    Altima             2.5 S  Sedan    automatic
# 15     2015      Nissan    Altima             2.5 S  Sedan    automatic
# 23     2015        Audi        A3  1.8 TFSI Premium  Sedan    automatic
# 34     2015         Kia   Sorento                LX    SUV    automatic
# 36     2015   Chevrolet  Suburban               LTZ    SUV    automatic
# ...     ...         ...       ...               ...    ...          ...
# 39091  2010      Toyota   Corolla                 S  Sedan    automatic
# 39092  2010  Volkswagen        CC        Sport PZEV  Sedan    automatic
# 41170  2015       Mazda      CX-5           Touring    SUV    automatic
# 41173  2015         Kia   Sorento                LX    SUV    automatic
# 41175  2015         Kia   Sorento                LX    SUV    automatic
#
#                      vin state  condition  odometer  color interior  \
# ...

# %%
b=a.groupby('color')['mmr'].mean()
b=b.reset_index()

# %%
b
# Out:
#    color           mmr
# 0  black  15567.751479
# 1   gray  13617.356688

# %%
b.loc[0:,'mmr']
# Out:
# 0    15567.751479
# 1    13617.356688
# Name: mmr, dtype: float64

# %% [markdown]
# # task 4

# %%
x2=df [(df['year']==2013)| (df['year']==2014) | (df['year']==2015)]
x2.head()
# Out:
#     year    make    model   trim   body transmission                vin state  \
# 0   2015     Kia  Sorento     LX    SUV    automatic  5xyktca69fg566472    ca
# 1   2015     Kia  Sorento     LX    SUV    automatic  5xyktca69fg561319    ca
# 3   2015   Volvo      S60     T5  Sedan    automatic  yv1612tb4f1310987    ca
# 5   2015  Nissan   Altima  2.5 S  Sedan    automatic  1n4al3ap1fn326013    ca
# 11  2015     Kia   Optima     LX  Sedan    automatic  5xxgm4a73fg353538    ca
#
#     condition  odometer  color interior  \
# 0         5.0   16639.0  white    black
# 1         5.0    9393.0  white    beige
# 3         4.1   14282.0  white    black
# 5         1.0    5554.0   gray    black
# 11        4.8    2034.0    red      tan
#
#                                                seller      mmr  sellingprice  \
# 0                             kia motors america, inc  20500.0       21500.0
# 1                             kia motors america, inc  20800.0       21500.0
# ...

# %%
x2=df.groupby(['color'])['color'].agg(['count']).sort_values(by='count',ascending=False)
x2
# Out:
#            count
# color
# black        507
# white        432
# silver       335
# gray         314
# blue         215
# red          162
# green        107
# gold          43
# burgundy      39
# —             29
# beige         26
# brown         18
# orange         8
# purple         8
# charcoal       4
# off-white      3
# yellow         2
# lime           1

# %% [markdown]
# # task 5

# %%
b1=df[(df['body']=='SUV') & (df['saledate']=='Fri Dec 19 2014 09:00:00 GMT-0800 (PST)')]
c=b1['body'].count()
c
# Out:
# 534

# %%
b2=df[(df['body']=='SUV') & (df['saledate']=='Thu Jan 15 2015 04:30:00 GMT-0800 (PST)')]
d=b2['body'].count()
d
# Out:
# 25

# %% [markdown]
# # task 6

# %%
col=list(df.columns)
index=col.index('sellingprice')
df.insert(index+1,column='Discountedprice',value=0)

# %%
df.loc[df['make'].isin(['Ford','Chevrolet']),'Discountedprice']=df['sellingprice']*.9

# %%
df.loc[df(['make']!='Ford') & (df['make']!='Chevrolet'),'Discountedprice']=df['sellingprice']*.8

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca        4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca        4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca        4.3    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america, inc  20500.0       21500.0
# ...

# %% [markdown]
# # task 7

# %%
df.isnull().sum()
# Out:
# year                0
# make              191
# model             193
# trim              340
# body             1278
# transmission     5452
# vin                 0
# state               1
# condition       11100
# odometer           69
# color             125
# interior          125
# seller              1
# mmr                 1
# sellingprice        1
# saledate            1
# dtype: int64

# %%
df=df.fillna(method='ffill')
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64
