# %% [markdown]
# # sprint_3_practice

# %%
import pandas as pd

# %%
df=pd.read_csv("DS1_C4_S3_Loan_Data_Practice.csv.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# # Task 1

# %%
df[(df['Education']=='Graduate') & (df['Gender']=='Male') & (df['Loan_Status']=='Y')].head()
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
# 8  LP001018   Male     Yes          2  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 2             3000                0.0          66               360
# 4             6000                0.0         141               360
# 5             5417             4196.0         267               360
# 8             4006             1526.0         168               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 2               1         Urban           Y
# 4               1         Urban           Y
# ...

# %% [markdown]
# # task 2

# %%
df[(df['Gender']=='Female') &  (df['ApplicantIncome']>4000) & (df['Self_Employed']=='Yes')].head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 113  LP001392  Female      No          1  Graduate           Yes
# 353  LP002142  Female     Yes          0  Graduate           Yes
# 370  LP002194  Female      No          0  Graduate           Yes
# 404  LP002301  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0         286               360
# 113             7451                0.0         146               360
# 353             5500                0.0         105               360
# 370            15759                0.0          55               360
# 404             7441                0.0         194               360
#
#      Credit_History Property_Area Loan_Status
# 54                0         Urban           N
# 113               1     Semiurban           Y
# ...

# %%
df.shape[0]
# Out:
# 614

# %% [markdown]
# # task 3

# %%
df[(df['Property_Area']=='Rural') & (df['Dependents']=='3+') & (df['Loan_Status']=='Y')].head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 126            23803                0.0         370               360
# 213             5703                0.0         130               360
# 255             3083                0.0         255               360
# 324            15000                0.0         300               360
# 352             2666             2083.0          95               360
#
#      Credit_History Property_Area Loan_Status
# 126               1         Rural           Y
# ...

# %% [markdown]
# # task 4

# %%
df[(df['LoanAmount']>=290)]['ApplicantIncome'].mean()
# Out:
# 17736.878787878788

# %% [markdown]
# # task 5

# %%
x=df[(df['Married']=='No') & (df['Self_Employed']=='Yes')]

# %%
x.head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 29   LP001087  Female      No          2      Graduate           Yes
# 32   LP001097    Male      No          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 29              3750             2083.0         120               360
# 32              4692                0.0         106               360
# 95              6782                0.0         146               360
# 107             7333                0.0         120               360
# 113             7451                0.0         146               360
#
#      Credit_History Property_Area Loan_Status
# 29                1     Semiurban           Y
# ...

# %%
x['Gender'].value_counts()
# Out:
# Male      25
# Female    15
# Name: Gender, dtype: int64

# %% [markdown]
# # task 6

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
df[(df['Property_Area']=='Urban')]['ApplicantIncome'].mean()
# Out:
# 5398.247524752475

# %%
df[(df['Property_Area']=='Rural')]['ApplicantIncome'].mean()
# Out:
# 5554.083798882682

# %%
df[(df['Property_Area']=='Semiurban')]['ApplicantIncome'].mean()
# Out:
# 5292.261802575107

# %% [markdown]
# # method 2

# %%
df[(df['Property_Area']=='Urban')][['Property_Area','ApplicantIncome']]
# Out:
#     Property_Area  ApplicantIncome
# 0           Urban             5849
# 2           Urban             3000
# 3           Urban             2583
# 4           Urban             6000
# 5           Urban             5417
# ..            ...              ...
# 600         Urban              416
# 602         Urban             5703
# 605         Urban             2400
# 611         Urban             8072
# 612         Urban             7583
#
# [202 rows x 2 columns]

# %%
df[(df['Property_Area']=='Rural')][['Property_Area','ApplicantIncome']]
# Out:
#     Property_Area  ApplicantIncome
# 1           Rural             4583
# 13          Rural             1853
# 18          Rural             4887
# 23          Rural             3365
# 32          Rural             4692
# ..            ...              ...
# 603         Rural             3676
# 607         Rural             3987
# 608         Rural             3232
# 609         Rural             2900
# 610         Rural             4106
#
# [179 rows x 2 columns]

# %%
df[(df['Property_Area']=='Semiurban')][['Property_Area','ApplicantIncome']]
# Out:
#     Property_Area  ApplicantIncome
# 7       Semiurban             3036
# 9       Semiurban            12841
# 22      Semiurban             2600
# 24      Semiurban             3717
# 25      Semiurban             9560
# ..            ...              ...
# 592     Semiurban             9357
# 597     Semiurban             2987
# 604     Semiurban            12000
# 606     Semiurban             3400
# 613     Semiurban             4583
#
# [233 rows x 2 columns]

# %% [markdown]
# # task 7

# %%
df[(df.Married == 'Yes') & (df['CoapplicantIncome'] < df[df.Married == 'Yes']['CoapplicantIncome'].mean()) & (df.Loan_Status == 'Y')]
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 1             4583             1508.0         128               360
# 2             3000                0.0          66               360
# 3             2583             2358.0         120               360
# 4             6000                0.0         141               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %% [markdown]
# # task 8

# %%
df[(df['Education']=='Graduate') & (df['ApplicantIncome']>10256) & (df['ApplicantIncome']<150000)]
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 1             4583             1508.0         128               360
# 2             3000                0.0          66               360
# 3             2583             2358.0         120               360
# 4             6000                0.0         141               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...
